# %%
kB = 1.380649e-2 # 10-21J/K

σ = 0.340 # 10-9 m
ϵ = 1.67 # 10-21 J
m = 66.34 # 10-27 kg

T=87.3
√(2kB*T/m*1e6)
# Out:
# 190.62331922980334

# %%
using Plots

# %%
xs = [1,2,3,4,5]
ys = [1,2,3,4,5]
zs = [1,2,3,2,1]
# Out:
# 5-element Vector{Int64}:
#  1
#  2
#  3
#  2
#  1

# %%
plot(xs,ys,marker_z=zs,st=:scatter)
